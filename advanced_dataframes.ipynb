# %%
# advanced_dataframes_exercises

# %%
import numpy as np
import pandas as pd

# %%
from env import host, user, password

# %%
url = f'mysql+pymysql://{user}:{password}@{host}/employees'

# %%
pd.read_sql('SELECT * FROM employees LIMIT 5 OFFSET 50', url)
# Out:
#    emp_no  birth_date first_name  last_name gender   hire_date
# 0   10051  1953-07-28   Hidefumi      Caine      M  1992-10-15
# 1   10052  1961-02-26     Heping     Nitsch      M  1988-05-21
# 2   10053  1954-09-13     Sanjiv   Zschoche      F  1986-02-04
# 3   10054  1957-04-04     Mayumi  Schueller      M  1995-03-13
# 4   10055  1956-06-06     Georgy     Dredge      M  1992-04-27

# %%
sql = '''
SELECT
    emp_no,
    first_name,
    last_name
FROM employees
WHERE gender = 'F'
LIMIT 100
'''

# %%
pd.read_sql(sql,url)
# Out:
#     emp_no  first_name  last_name
# 0    10002     Bezalel     Simmel
# 1    10006      Anneke    Preusig
# 2    10007     Tzvetan  Zielinski
# 3    10009      Sumant       Peac
# 4    10010   Duangkaew   Piveteau
# ..     ...         ...        ...
# 95   10245  Ramalingam      Gente
# 96   10247        Heon    Riefers
# 97   10248  Frederique   Tempesti
# 98   10252     Shirish    Wegerle
# 99   10253       Zsolt    Salinas
#
# [100 rows x 3 columns]

# %%
query = '''
SELECT
    t.title as title,
    d.dept_name as dept_name
FROM titles t
JOIN dept_emp USING (emp_no)
JOIN departments d USING (dept_no)
LIMIT 100
'''

title_dept = pd.read_sql(query, url)
title_dept.head()
# Out:
#           title         dept_name
# 0         Staff  Customer Service
# 1  Senior Staff  Customer Service
# 2         Staff  Customer Service
# 3  Senior Staff  Customer Service
# 4         Staff  Customer Service

# %%
def get_db_url(db_name, user=user, host=host, password=password):
    '''
    get_db_url accepts a database name, username, hostname, password 
    and returns a url connection string formatted to work with codeup's 
    sql database.
    Default values from env.py are provided for user, host, and password.
    '''
    return f'mysql+pymysql://{user}:{password}@{host}/{db_name}'

# %%
connection_string = get_db_url(user, host, password, 'employees')

# %%
pd.read_sql(query, connection_string)
# Out:
#            title         dept_name
# 0          Staff  Customer Service
# 1   Senior Staff  Customer Service
# 2          Staff  Customer Service
# 3   Senior Staff  Customer Service
# 4          Staff  Customer Service
# ..           ...               ...
# 95  Senior Staff  Customer Service
# 96         Staff  Customer Service
# 97  Senior Staff  Customer Service
# 98  Senior Staff  Customer Service
# 99         Staff  Customer Service
#
# [100 rows x 2 columns]

# %%
# If I intentionally make an error in the connection string (in this case, 
# I misspelled the database name), I get this error when I run the sql query:
# OperationalError: (pymysql.err.OperationalError) (1044, "Access denied for 
# user 'pagel_2179'@'%' to database 'employes'")

connection_string = get_db_url(user, host, password, 'employes')
pd.read_sql(query, connection_string)

# %%
# If I intentionally make an error in the SQL query (in this case,
# I removed the comma after title in the SELECT statement), I get this error:
# ProgrammingError: (pymysql.err.ProgrammingError) (1064, "You have an error 
# in your SQL syntax; ...
# The error looks very similar to the error that mysql would give if I 
# ran it in MySQLWorkBench

connection_string = get_db_url(user, host, password, 'employees')
error_query = '''
SELECT
    t.title as title
    d.dept_name as dept_name
FROM titles t
JOIN dept_emp USING (emp_no)
JOIN departments d USING (dept_no)
LIMIT 100
'''
pd.read_sql(error_query, connection_string)

# %%
# Read the employees and titles tables into two separate DataFrames.

employees_db_connect_string = get_db_url(user, host, password, 'employees')
employees_query = '''
    SELECT *
    FROM employees
'''
titles_query = '''
    SELECT *
    FROM titles
'''

# %%
employees_df = pd.read_sql(employees_query, employees_db_connect_string)

# %%
titles_df = pd.read_sql(titles_query, employees_db_connect_string)

# %%
employees_df

# %%
titles_df

# %%
# How many rows and columns do you have in each DataFrame? Is that what you expected?

# employees_df had 300024 rows x 6 columns
# titles_df had 443308 rows x 4 columns
employees_df.shape

# %%
titles_df.shape
# Out:
# (443308, 4)

# %%
# Display the summary statistics for each DataFrame.

employees_df.info()
#employees_df.describe()
titles_df.info()

# %%
# How many unique titles are in the titles DataFrame?

print("The number of unique titles in the titles DataFrame = ")
titles_df['title'].nunique()

# %%
# What is the oldest date in the to_date column?

print("The oldest date in the to_date columns are: ")
print(titles_df['to_date'].min())

# %%
# What is the most recent date in the to_date column?

print("The most recent date in the to_date columns are: ")
print(titles_df['to_date'].max())
# Out:
# The most recent date in the to_date columns are:
# 9999-01-01

# %%
# The most recent date in the to_date column that is not 9999-01-01 ?

(titles_df['to_date'][titles_df['to_date'] != titles_df['to_date'].max()]).max()
# Out:
# datetime.date(2002, 8, 1)

# %%
###### Exercise Part 2 ########

# %%
#     Copy the users and roles DataFrames from the examples above.

# Create the users DataFrame

users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
# Create the roles DataFrame

roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %%
#     What is the result of using a right join on the DataFrames?

pd.merge(users, roles, how='right', left_on='role_id', right_on='id')
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0     1      admin
# 1   2.0    joe      2.0     2     author
# 2   3.0  sally      3.0     3   reviewer
# 3   4.0   adam      3.0     3   reviewer
# 4   NaN    NaN      NaN     4  commenter

# %%
#     What is the result of using an outer join on the DataFrames?

pd.merge(users, roles, how='outer', left_on='role_id', right_on='id', indicator=True)
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0   1.0      admin        both
# 1   2.0    joe      2.0   2.0     author        both
# 2   3.0  sally      3.0   3.0   reviewer        both
# 3   4.0   adam      3.0   3.0   reviewer        both
# 4   5.0   jane      NaN   NaN        NaN   left_only
# 5   6.0   mike      NaN   NaN        NaN   left_only
# 6   NaN    NaN      NaN   4.0  commenter  right_only

# %%
#     What happens if you drop the foreign keys from the DataFrames and try to merge them?

# It doesn't work very well
users_without_role_id = users.drop(columns=['role_id'])
pd.merge(users_without_role_id, roles, how='outer', on = 'id')
# Out:
#    id name_x     name_y
# 0   1    bob      admin
# 1   2    joe     author
# 2   3  sally   reviewer
# 3   4   adam  commenter
# 4   5   jane        NaN
# 5   6   mike        NaN

# %%
#     Load the mpg dataset from PyDataset.

from pydataset import data 

mpg = data('mpg')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
# 234  midsize
#
# [234 rows x 11 columns]

# %%
#     Output and read the documentation for the mpg dataset.

data('mpg', show_doc=True)
print(mpg.head())
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.
#
#
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
#     How many rows and columns are in the dataset?

# this is also in the show_doc=True documentation
mpg.shape
# Out:
# (234, 11)

# %%
#     Check out your column names and perform any cleanup you may want on them.

mpg = mpg.rename(columns={'cty': 'city', 'hwy': 'highway', 'class': 'car_class'})
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#     car_class
# 1     compact
# 2     compact
# 3     compact
# 4     compact
# 5     compact
# ..        ...
# 230   midsize
# 231   midsize
# 232   midsize
# 233   midsize
# 234   midsize
#
# [234 rows x 11 columns]

# %%
#     Display the summary statistics for the dataset.

mpg.describe(include='all')
# Out:
#        manufacturer        model       displ         year         cyl  \
# count           234          234  234.000000   234.000000  234.000000
# unique           15           38         NaN          NaN         NaN
# top           dodge  caravan 2wd         NaN          NaN         NaN
# freq             37           11         NaN          NaN         NaN
# mean            NaN          NaN    3.471795  2003.500000    5.888889
# std             NaN          NaN    1.291959     4.509646    1.611534
# min             NaN          NaN    1.600000  1999.000000    4.000000
# 25%             NaN          NaN    2.400000  1999.000000    4.000000
# 50%             NaN          NaN    3.300000  2003.500000    6.000000
# 75%             NaN          NaN    4.600000  2008.000000    8.000000
# max             NaN          NaN    7.000000  2008.000000    8.000000
#
#            trans  drv        city     highway   fl car_class
# count        234  234  234.000000  234.000000  234       234
# unique        10    3         NaN         NaN    5         7
# top     auto(l4)    f         NaN         NaN    r       suv
# freq          83  106         NaN         NaN  168        62
# mean         NaN  NaN   16.858974   23.440171  NaN       NaN
# std          NaN  NaN    4.255946    5.954643  NaN       NaN
# min          NaN  NaN    9.000000   12.000000  NaN       NaN
# 25%          NaN  NaN   14.000000   18.000000  NaN       NaN
# 50%          NaN  NaN   17.000000   24.000000  NaN       NaN
# 75%          NaN  NaN   19.000000   27.000000  NaN       NaN
# max          NaN  NaN   35.000000   44.000000  NaN       NaN

# %%
#     How many different manufacturers are there?

# Two ways. First, use nunique to count the number of unique manufacturers
mpg.manufacturer.nunique()

# OR use groupby and the 'manufacturer' column and then take the lenth
len(mpg.groupby('manufacturer').manufacturer.count())
# Out:
# 15

# %%
#     How many different models are there?

# Same two ways
mpg.model.nunique()

len(mpg.groupby('model').model.count())
# Out:
# 38

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4    auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16       26  p
#
#   car_class
# 1   compact
# 2   compact
# 3   compact
# 4   compact
# 5   compact

# %%
#     Create a column named mileage_difference like you did in the DataFrames exercises; this column 
# should contain the difference between highway and city mileage for each car.

# could do this the same way we did before:
#  mpg['mileage_difference'] = mpg.highway - mpg.city

# However, here is a way using pd.concat:
mileage_diff_df = pd.DataFrame(mpg.highway - mpg.city, columns=['mileage_difference'])
mpg = pd.concat([mpg, mileage_diff_df], axis = 1)
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#     car_class  mileage_difference
# 1     compact                  11
# 2     compact                   8
# 3     compact                  11
# 4     compact                   9
# 5     compact                  10
# ..        ...                 ...
# 230   midsize                   9
# 231   midsize                   8
# 232   midsize                  10
# 233   midsize                   8
# 234   midsize                   9
#
# [234 rows x 12 columns]

# %%
#     Create a column named average_mileage like you did in the DataFrames exercises; this is the mean 
# of the city and highway mileage.

average_mileage = pd.DataFrame(((mpg.highway + mpg.city) / 2), columns = ['average_mileage'])
mpg = pd.concat([mpg, average_mileage], axis = 1)
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#     car_class  mileage_difference  is_automatic  average_mileage
# 1     compact                  11          True             23.5
# 2     compact                   8         False             25.0
# 3     compact                  11         False             25.5
# 4     compact                   9          True             25.5
# 5     compact                  10          True             21.0
# ..        ...                 ...           ...              ...
# 230   midsize                   9          True             23.5
# 231   midsize                   8         False             25.0
# 232   midsize                  10          True             21.0
# 233   midsize                   8         False             22.0
# 234   midsize                   9          True             21.5
#
# [234 rows x 14 columns]

# %%
#     Create a new column on the mpg dataset named is_automatic that holds boolean values denoting whether 
# the car has an automatic transmission.

# could do this:
# mpg['is_automatic'] = mpg.trans.str.contains('auto')
# mpg
# mpg = mpg.drop(columns = ['is_automatic'])
 
# OR

# is_auto_df = pd.DataFrame(np.where(mpg.trans.str.contains('auto'), True, False), columns = ['is_automatic'])
# is_auto_df
# mpg = pd.concat([mpg, is_auto_df], axis=1)

# is_auto_df has an index that starts with 0 which messes this up

# This works:
mpg.trans.value_counts()
mpg.trans.str.contains('auto')
mpg['is_auto'] = mpg.trans.str.contains('auto')
mpg = mpg.rename(columns = {'is_auto': 'is_automatic'})
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#     car_class  mileage_difference  is_automatic
# 1     compact                  11          True
# 2     compact                   8         False
# 3     compact                  11         False
# 4     compact                   9          True
# 5     compact                  10          True
# ..        ...                 ...           ...
# 230   midsize                   9          True
# 231   midsize                   8         False
# 232   midsize                  10          True
# 233   midsize                   8         False
# 234   midsize                   9          True
#
# [234 rows x 13 columns]

# %%
#     Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?

mpg

# get all of the average mpg's gouped by manufacturer and sort the highest to lowest
mpg.groupby('manufacturer').average_mileage.mean().sort_values(ascending=False)

# OR to just get the max average mileage with the manufacturer:
# pd.DataFrame(mpg.groupby('manufacturer').average_mileage.mean().sort_values(ascending=False)).iloc[0:1,:]
# Out:
# manufacturer
# honda         28.500000
# volkswagen    25.074074
# hyundai       22.750000
# subaru        22.428571
# audi          22.027778
# toyota        21.720588
# pontiac       21.700000
# nissan        21.346154
# chevrolet     18.447368
# ford          16.680000
# mercury       15.625000
# jeep          15.562500
# dodge         15.540541
# lincoln       14.166667
# land rover    14.000000
# Name: average_mileage, dtype: float64

# %%
#     Do automatic or manual cars have better miles per gallon?

# manual cars have better mpg's on average
pd.DataFrame(mpg.groupby('is_automatic').average_mileage.mean())
# Out:
#               average_mileage
# is_automatic
# False               22.227273
# True                19.130573

# %%
mpg.groupby('manufacturer').model.count()
# Out:
# manufacturer
# audi          18
# chevrolet     19
# dodge         37
# ford          25
# honda          9
# hyundai       14
# jeep           8
# land rover     4
# lincoln        3
# mercury        4
# nissan        13
# pontiac        5
# subaru        14
# toyota        34
# volkswagen    27
# Name: model, dtype: int64

# %%
is_auto_mask = np.where(mpg.trans.str.contains('auto'), True, False)
mpg[is_auto_mask]
# Out:
#     manufacturer                   model  displ    year  cyl     trans  drv  \
# 1           audi                      a4    1.8  1999.0  4.0  auto(l5)    f
# 4           audi                      a4    2.0  2008.0  4.0  auto(av)    f
# 5           audi                      a4    2.8  1999.0  6.0  auto(l5)    f
# 7           audi                      a4    3.1  2008.0  6.0  auto(av)    f
# 9           audi              a4 quattro    1.8  1999.0  4.0  auto(l5)    4
# 11          audi              a4 quattro    2.0  2008.0  4.0  auto(s6)    4
# 12          audi              a4 quattro    2.8  1999.0  6.0  auto(l5)    4
# 14          audi              a4 quattro    3.1  2008.0  6.0  auto(s6)    4
# 16          audi              a6 quattro    2.8  1999.0  6.0  auto(l5)    4
# 17          audi              a6 quattro    3.1  2008.0  6.0  auto(s6)    4
# 18          audi              a6 quattro    4.2  2008.0  8.0  auto(s6)    4
# 19     chevrolet      c1500 suburban 2wd    5.3  2008.0  8.0  auto(l4)    r
# 20     chevrolet      c1500 suburban 2wd    5.3  2008.0  8.0  auto(l4)    r
# 21     chevrolet      c1500 suburban 2wd    5.3  2008.0  8.0  auto(l4)    r
# 22     chevrolet      c1500 suburban 2wd    5.7  1999.0  8.0  auto(l4)    r
# 23     chevrolet      c1500 suburban 2wd    6.0  2008.0  8.0  auto(l4)    r
# 25     chevrolet                corvette    5.7  1999.0  8.0  auto(l4)    r
# 27     chevrolet                corvette    6.2  2008.0  8.0  auto(s6)    r
# 29     chevrolet         k1500 tahoe 4wd    5.3  2008.0  8.0  auto(l4)    4
# 30     chevrolet         k1500 tahoe 4wd    5.3  2008.0  8.0  auto(l4)    4
# 31     chevrolet         k1500 tahoe 4wd    5.7  1999.0  8.0  auto(l4)    4
# 32     chevrolet         k1500 tahoe 4wd    6.5  1999.0  8.0  auto(l4)    4
# 33     chevrolet                  malibu    2.4  1999.0  4.0  auto(l4)    f
# 34     chevrolet                  malibu    2.4  2008.0  4.0  auto(l4)    f
# 35     chevrolet                  malibu    3.1  1999.0  6.0  auto(l4)    f
# 36     chevrolet                  malibu    3.5  2008.0  6.0  auto(l4)    f
# 37     chevrolet                  malibu    3.6  2008.0  6.0  auto(s6)    f
# 38         dodge             caravan 2wd    2.4  1999.0  4.0  auto(l3)    f
# 39         dodge             caravan 2wd    3.0  1999.0  6.0  auto(l4)    f
# 40         dodge             caravan 2wd    3.3  1999.0  6.0  auto(l4)    f
# 41         dodge             caravan 2wd    3.3  1999.0  6.0  auto(l4)    f
# 42         dodge             caravan 2wd    3.3  2008.0  6.0  auto(l4)    f
# 43         dodge             caravan 2wd    3.3  2008.0  6.0  auto(l4)    f
# 44         dodge             caravan 2wd    3.3  2008.0  6.0  auto(l4)    f
# 45         dodge             caravan 2wd    3.8  1999.0  6.0  auto(l4)    f
# 46         dodge             caravan 2wd    3.8  1999.0  6.0  auto(l4)    f
# 47         dodge             caravan 2wd    3.8  2008.0  6.0  auto(l6)    f
# 48         dodge             caravan 2wd    4.0  2008.0  6.0  auto(l6)    f
# 50         dodge       dakota pickup 4wd    3.7  2008.0  6.0  auto(l4)    4
# 51         dodge       dakota pickup 4wd    3.9  1999.0  6.0  auto(l4)    4
# 53         dodge       dakota pickup 4wd    4.7  2008.0  8.0  auto(l5)    4
# 54         dodge       dakota pickup 4wd    4.7  2008.0  8.0  auto(l5)    4
# 55         dodge       dakota pickup 4wd    4.7  2008.0  8.0  auto(l5)    4
# 57         dodge       dakota pickup 4wd    5.2  1999.0  8.0  auto(l4)    4
# 58         dodge             durango 4wd    3.9  1999.0  6.0  auto(l4)    4
# 59         dodge             durango 4wd    4.7  2008.0  8.0  auto(l5)    4
# 60         dodge             durango 4wd    4.7  2008.0  8.0  auto(l5)    4
# 61         dodge             durango 4wd    4.7  2008.0  8.0  auto(l5)    4
# 62         dodge             durango 4wd    5.2  1999.0  8.0  auto(l4)    4
# 63         dodge             durango 4wd    5.7  2008.0  8.0  auto(l5)    4
# 64         dodge             durango 4wd    5.9  1999.0  8.0  auto(l4)    4
# 66         dodge     ram 1500 pickup 4wd    4.7  2008.0  8.0  auto(l5)    4
# 67         dodge     ram 1500 pickup 4wd    4.7  2008.0  8.0  auto(l5)    4
# 68         dodge     ram 1500 pickup 4wd    4.7  2008.0  8.0  auto(l5)    4
# 71         dodge     ram 1500 pickup 4wd    5.2  1999.0  8.0  auto(l4)    4
# 73         dodge     ram 1500 pickup 4wd    5.7  2008.0  8.0  auto(l5)    4
# 74         dodge     ram 1500 pickup 4wd    5.9  1999.0  8.0  auto(l4)    4
# 75          ford          expedition 2wd    4.6  1999.0  8.0  auto(l4)    r
# 76          ford          expedition 2wd    5.4  1999.0  8.0  auto(l4)    r
# 77          ford          expedition 2wd    5.4  2008.0  8.0  auto(l6)    r
# 78          ford            explorer 4wd    4.0  1999.0  6.0  auto(l5)    4
# 80          ford            explorer 4wd    4.0  1999.0  6.0  auto(l5)    4
# 81          ford            explorer 4wd    4.0  2008.0  6.0  auto(l5)    4
# 82          ford            explorer 4wd    4.6  2008.0  8.0  auto(l6)    4
# 83          ford            explorer 4wd    5.0  1999.0  8.0  auto(l4)    4
# 84          ford         f150 pickup 4wd    4.2  1999.0  6.0  auto(l4)    4
# 87          ford         f150 pickup 4wd    4.6  1999.0  8.0  auto(l4)    4
# 88          ford         f150 pickup 4wd    4.6  2008.0  8.0  auto(l4)    4
# 89          ford         f150 pickup 4wd    5.4  1999.0  8.0  auto(l4)    4
# 90          ford         f150 pickup 4wd    5.4  2008.0  8.0  auto(l4)    4
# 92          ford                 mustang    3.8  1999.0  6.0  auto(l4)    r
# 94          ford                 mustang    4.0  2008.0  6.0  auto(l5)    r
# 95          ford                 mustang    4.6  1999.0  8.0  auto(l4)    r
# 98          ford                 mustang    4.6  2008.0  8.0  auto(l5)    r
# 101        honda                   civic    1.6  1999.0  4.0  auto(l4)    f
# 104        honda                   civic    1.6  1999.0  4.0  auto(l4)    f
# 106        honda                   civic    1.8  2008.0  4.0  auto(l5)    f
# 107        honda                   civic    1.8  2008.0  4.0  auto(l5)    f
# 109      hyundai                  sonata    2.4  1999.0  4.0  auto(l4)    f
# 111      hyundai                  sonata    2.4  2008.0  4.0  auto(l4)    f
# 113      hyundai                  sonata    2.5  1999.0  6.0  auto(l4)    f
# 115      hyundai                  sonata    3.3  2008.0  6.0  auto(l5)    f
# 116      hyundai                 tiburon    2.0  1999.0  4.0  auto(l4)    f
# 119      hyundai                 tiburon    2.0  2008.0  4.0  auto(l4)    f
# 120      hyundai                 tiburon    2.7  2008.0  6.0  auto(l4)    f
# 123         jeep      grand cherokee 4wd    3.0  2008.0  6.0  auto(l5)    4
# 124         jeep      grand cherokee 4wd    3.7  2008.0  6.0  auto(l5)    4
# 125         jeep      grand cherokee 4wd    4.0  1999.0  6.0  auto(l4)    4
# 126         jeep      grand cherokee 4wd    4.7  1999.0  8.0  auto(l4)    4
# 127         jeep      grand cherokee 4wd    4.7  2008.0  8.0  auto(l5)    4
# 128         jeep      grand cherokee 4wd    4.7  2008.0  8.0  auto(l5)    4
# 129         jeep      grand cherokee 4wd    5.7  2008.0  8.0  auto(l5)    4
# 130         jeep      grand cherokee 4wd    6.1  2008.0  8.0  auto(l5)    4
# 131   land rover             range rover    4.0  1999.0  8.0  auto(l4)    4
# 132   land rover             range rover    4.2  2008.0  8.0  auto(s6)    4
# 133   land rover             range rover    4.4  2008.0  8.0  auto(s6)    4
# 134   land rover             range rover    4.6  1999.0  8.0  auto(l4)    4
# 135      lincoln           navigator 2wd    5.4  1999.0  8.0  auto(l4)    r
# 136      lincoln           navigator 2wd    5.4  1999.0  8.0  auto(l4)    r
# 137      lincoln           navigator 2wd    5.4  2008.0  8.0  auto(l6)    r
# 138      mercury         mountaineer 4wd    4.0  1999.0  6.0  auto(l5)    4
# 139      mercury         mountaineer 4wd    4.0  2008.0  6.0  auto(l5)    4
# 140      mercury         mountaineer 4wd    4.6  2008.0  8.0  auto(l6)    4
# 141      mercury         mountaineer 4wd    5.0  1999.0  8.0  auto(l4)    4
# 143       nissan                  altima    2.4  1999.0  4.0  auto(l4)    f
# 144       nissan                  altima    2.5  2008.0  4.0  auto(av)    f
# 147       nissan                  altima    3.5  2008.0  6.0  auto(av)    f
# 148       nissan                  maxima    3.0  1999.0  6.0  auto(l4)    f
# 150       nissan                  maxima    3.5  2008.0  6.0  auto(av)    f
# 151       nissan          pathfinder 4wd    3.3  1999.0  6.0  auto(l4)    4
# 153       nissan          pathfinder 4wd    4.0  2008.0  6.0  auto(l5)    4
# 154       nissan          pathfinder 4wd    5.6  2008.0  8.0  auto(s5)    4
# 155      pontiac              grand prix    3.1  1999.0  6.0  auto(l4)    f
# 156      pontiac              grand prix    3.8  1999.0  6.0  auto(l4)    f
# 157      pontiac              grand prix    3.8  1999.0  6.0  auto(l4)    f
# 158      pontiac              grand prix    3.8  2008.0  6.0  auto(l4)    f
# 159      pontiac              grand prix    5.3  2008.0  8.0  auto(s4)    f
# 161       subaru            forester awd    2.5  1999.0  4.0  auto(l4)    4
# 164       subaru            forester awd    2.5  2008.0  4.0  auto(l4)    4
# 165       subaru            forester awd    2.5  2008.0  4.0  auto(l4)    4
# 166       subaru             impreza awd    2.2  1999.0  4.0  auto(l4)    4
# 169       subaru             impreza awd    2.5  1999.0  4.0  auto(l4)    4
# 170       subaru             impreza awd    2.5  2008.0  4.0  auto(s4)    4
# 171       subaru             impreza awd    2.5  2008.0  4.0  auto(s4)    4
# 175       toyota             4runner 4wd    2.7  1999.0  4.0  auto(l4)    4
# 176       toyota             4runner 4wd    3.4  1999.0  6.0  auto(l4)    4
# 178       toyota             4runner 4wd    4.0  2008.0  6.0  auto(l5)    4
# 179       toyota             4runner 4wd    4.7  2008.0  8.0  auto(l5)    4
# 181       toyota                   camry    2.2  1999.0  4.0  auto(l4)    f
# 183       toyota                   camry    2.4  2008.0  4.0  auto(l5)    f
# 184       toyota                   camry    3.0  1999.0  6.0  auto(l4)    f
# 186       toyota                   camry    3.5  2008.0  6.0  auto(s6)    f
# 187       toyota            camry solara    2.2  1999.0  4.0  auto(l4)    f
# 190       toyota            camry solara    2.4  2008.0  4.0  auto(s5)    f
# 191       toyota            camry solara    3.0  1999.0  6.0  auto(l4)    f
# 193       toyota            camry solara    3.3  2008.0  6.0  auto(s5)    f
# 194       toyota                 corolla    1.8  1999.0  4.0  auto(l3)    f
# 195       toyota                 corolla    1.8  1999.0  4.0  auto(l4)    f
# 198       toyota                 corolla    1.8  2008.0  4.0  auto(l4)    f
# 199       toyota  land cruiser wagon 4wd    4.7  1999.0  8.0  auto(l4)    4
# 200       toyota  land cruiser wagon 4wd    5.7  2008.0  8.0  auto(s6)    4
# 202       toyota       toyota tacoma 4wd    2.7  1999.0  4.0  auto(l4)    4
# 205       toyota       toyota tacoma 4wd    3.4  1999.0  6.0  auto(l4)    4
# 207       toyota       toyota tacoma 4wd    4.0  2008.0  6.0  auto(l5)    4
# 209   volkswagen                     gti    2.0  1999.0  4.0  auto(l4)    f
# 211   volkswagen                     gti    2.0  2008.0  4.0  auto(s6)    f
# 215   volkswagen                   jetta    2.0  1999.0  4.0  auto(l4)    f
# 216   volkswagen                   jetta    2.0  2008.0  4.0  auto(s6)    f
# 218   volkswagen                   jetta    2.5  2008.0  5.0  auto(s6)    f
# 220   volkswagen                   jetta    2.8  1999.0  6.0  auto(l4)    f
# 223   volkswagen              new beetle    1.9  1999.0  4.0  auto(l4)    f
# 225   volkswagen              new beetle    2.0  1999.0  4.0  auto(l4)    f
# 227   volkswagen              new beetle    2.5  2008.0  5.0  auto(s6)    f
# 229   volkswagen                  passat    1.8  1999.0  4.0  auto(l5)    f
# 230   volkswagen                  passat    2.0  2008.0  4.0  auto(s6)    f
# 232   volkswagen                  passat    2.8  1999.0  6.0  auto(l5)    f
# 234   volkswagen                  passat    3.6  2008.0  6.0  auto(s6)    f
# 0            NaN                     NaN    NaN     NaN  NaN       NaN  NaN
#
#      city  highway   fl   car_class  mileage_difference  average_mileage  \
# 1    18.0     29.0    p     compact                11.0             23.5
# 4    21.0     30.0    p     compact                 9.0             25.5
# 5    16.0     26.0    p     compact                10.0             21.0
# 7    18.0     27.0    p     compact                 9.0             22.5
# 9    16.0     25.0    p     compact                 9.0             20.5
# 11   19.0     27.0    p     compact                 8.0             23.0
# 12   15.0     25.0    p     compact                10.0             20.0
# 14   17.0     25.0    p     compact                 8.0             21.0
# 16   15.0     24.0    p     midsize                 9.0             19.5
# 17   17.0     25.0    p     midsize                 8.0             21.0
# 18   16.0     23.0    p     midsize                 7.0             19.5
# 19   14.0     20.0    r         suv                 6.0             17.0
# 20   11.0     15.0    e         suv                 4.0             13.0
# 21   14.0     20.0    r         suv                 6.0             17.0
# 22   13.0     17.0    r         suv                 4.0             15.0
# 23   12.0     17.0    r         suv                 5.0             14.5
# 25   15.0     23.0    p     2seater                 8.0             19.0
# 27   15.0     25.0    p     2seater                10.0             20.0
# 29   14.0     19.0    r         suv                 5.0             16.5
# 30   11.0     14.0    e         suv                 3.0             12.5
# 31   11.0     15.0    r         suv                 4.0             13.0
# 32   14.0     17.0    d         suv                 3.0             15.5
# 33   19.0     27.0    r     midsize                 8.0             23.0
# 34   22.0     30.0    r     midsize                 8.0             26.0
# 35   18.0     26.0    r     midsize                 8.0             22.0
# 36   18.0     29.0    r     midsize                11.0             23.5
# 37   17.0     26.0    r     midsize                 9.0             21.5
# 38   18.0     24.0    r     minivan                 6.0             21.0
# 39   17.0     24.0    r     minivan                 7.0             20.5
# 40   16.0     22.0    r     minivan                 6.0             19.0
# 41   16.0     22.0    r     minivan                 6.0             19.0
# 42   17.0     24.0    r     minivan                 7.0             20.5
# 43   17.0     24.0    r     minivan                 7.0             20.5
# 44   11.0     17.0    e     minivan                 6.0             14.0
# 45   15.0     22.0    r     minivan                 7.0             18.5
# 46   15.0     21.0    r     minivan                 6.0             18.0
# 47   16.0     23.0    r     minivan                 7.0             19.5
# 48   16.0     23.0    r     minivan                 7.0             19.5
# 50   14.0     18.0    r      pickup                 4.0             16.0
# 51   13.0     17.0    r      pickup                 4.0             15.0
# 53   14.0     19.0    r      pickup                 5.0             16.5
# 54   14.0     19.0    r      pickup                 5.0             16.5
# 55    9.0     12.0    e      pickup                 3.0             10.5
# 57   11.0     15.0    r      pickup                 4.0             13.0
# 58   13.0     17.0    r         suv                 4.0             15.0
# 59   13.0     17.0    r         suv                 4.0             15.0
# 60    9.0     12.0    e         suv                 3.0             10.5
# 61   13.0     17.0    r         suv                 4.0             15.0
# 62   11.0     16.0    r         suv                 5.0             13.5
# 63   13.0     18.0    r         suv                 5.0             15.5
# 64   11.0     15.0    r         suv                 4.0             13.0
# 66    9.0     12.0    e      pickup                 3.0             10.5
# 67   13.0     17.0    r      pickup                 4.0             15.0
# 68   13.0     17.0    r      pickup                 4.0             15.0
# 71   11.0     15.0    r      pickup                 4.0             13.0
# 73   13.0     17.0    r      pickup                 4.0             15.0
# 74   11.0     15.0    r      pickup                 4.0             13.0
# 75   11.0     17.0    r         suv                 6.0             14.0
# 76   11.0     17.0    r         suv                 6.0             14.0
# 77   12.0     18.0    r         suv                 6.0             15.0
# 78   14.0     17.0    r         suv                 3.0             15.5
# 80   14.0     17.0    r         suv                 3.0             15.5
# 81   13.0     19.0    r         suv                 6.0             16.0
# 82   13.0     19.0    r         suv                 6.0             16.0
# 83   13.0     17.0    r         suv                 4.0             15.0
# 84   14.0     17.0    r      pickup                 3.0             15.5
# 87   13.0     16.0    r      pickup                 3.0             14.5
# 88   13.0     17.0    r      pickup                 4.0             15.0
# 89   11.0     15.0    r      pickup                 4.0             13.0
# 90   13.0     17.0    r      pickup                 4.0             15.0
# 92   18.0     25.0    r  subcompact                 7.0             21.5
# 94   16.0     24.0    r  subcompact                 8.0             20.0
# 95   15.0     21.0    r  subcompact                 6.0             18.0
# 98   15.0     22.0    r  subcompact                 7.0             18.5
# 101  24.0     32.0    r  subcompact                 8.0             28.0
# 104  24.0     32.0    r  subcompact                 8.0             28.0
# 106  25.0     36.0    r  subcompact                11.0             30.5
# 107  24.0     36.0    c  subcompact                12.0             30.0
# 109  18.0     26.0    r     midsize                 8.0             22.0
# 111  21.0     30.0    r     midsize                 9.0             25.5
# 113  18.0     26.0    r     midsize                 8.0             22.0
# 115  19.0     28.0    r     midsize                 9.0             23.5
# 116  19.0     26.0    r  subcompact                 7.0             22.5
# 119  20.0     27.0    r  subcompact                 7.0             23.5
# 120  17.0     24.0    r  subcompact                 7.0             20.5
# 123  17.0     22.0    d         suv                 5.0             19.5
# 124  15.0     19.0    r         suv                 4.0             17.0
# 125  15.0     20.0    r         suv                 5.0             17.5
# 126  14.0     17.0    r         suv                 3.0             15.5
# 127   9.0     12.0    e         suv                 3.0             10.5
# 128  14.0     19.0    r         suv                 5.0             16.5
# 129  13.0     18.0    r         suv                 5.0             15.5
# 130  11.0     14.0    p         suv                 3.0             12.5
# 131  11.0     15.0    p         suv                 4.0             13.0
# 132  12.0     18.0    r         suv                 6.0             15.0
# 133  12.0     18.0    r         suv                 6.0             15.0
# 134  11.0     15.0    p         suv                 4.0             13.0
# 135  11.0     17.0    r         suv                 6.0             14.0
# 136  11.0     16.0    p         suv                 5.0             13.5
# 137  12.0     18.0    r         suv                 6.0             15.0
# 138  14.0     17.0    r         suv                 3.0             15.5
# 139  13.0     19.0    r         suv                 6.0             16.0
# 140  13.0     19.0    r         suv                 6.0             16.0
# 141  13.0     17.0    r         suv                 4.0             15.0
# 143  19.0     27.0    r     compact                 8.0             23.0
# 144  23.0     31.0    r     midsize                 8.0             27.0
# 147  19.0     26.0    p     midsize                 7.0             22.5
# 148  18.0     26.0    r     midsize                 8.0             22.0
# 150  19.0     25.0    p     midsize                 6.0             22.0
# 151  14.0     17.0    r         suv                 3.0             15.5
# 153  14.0     20.0    p         suv                 6.0             17.0
# 154  12.0     18.0    p         suv                 6.0             15.0
# 155  18.0     26.0    r     midsize                 8.0             22.0
# 156  16.0     26.0    p     midsize                10.0             21.0
# 157  17.0     27.0    r     midsize                10.0             22.0
# 158  18.0     28.0    r     midsize                10.0             23.0
# 159  16.0     25.0    p     midsize                 9.0             20.5
# 161  18.0     24.0    r         suv                 6.0             21.0
# 164  20.0     26.0    r         suv                 6.0             23.0
# 165  18.0     23.0    p         suv                 5.0             20.5
# 166  21.0     26.0    r  subcompact                 5.0             23.5
# 169  19.0     26.0    r  subcompact                 7.0             22.5
# 170  20.0     25.0    p     compact                 5.0             22.5
# 171  20.0     27.0    r     compact                 7.0             23.5
# 175  16.0     20.0    r         suv                 4.0             18.0
# 176  15.0     19.0    r         suv                 4.0             17.0
# 178  16.0     20.0    r         suv                 4.0             18.0
# 179  14.0     17.0    r         suv                 3.0             15.5
# 181  21.0     27.0    r     midsize                 6.0             24.0
# 183  21.0     31.0    r     midsize                10.0             26.0
# 184  18.0     26.0    r     midsize                 8.0             22.0
# 186  19.0     28.0    r     midsize                 9.0             23.5
# 187  21.0     27.0    r     compact                 6.0             24.0
# 190  22.0     31.0    r     compact                 9.0             26.5
# 191  18.0     26.0    r     compact                 8.0             22.0
# 193  18.0     27.0    r     compact                 9.0             22.5
# 194  24.0     30.0    r     compact                 6.0             27.0
# 195  24.0     33.0    r     compact                 9.0             28.5
# 198  26.0     35.0    r     compact                 9.0             30.5
# 199  11.0     15.0    r         suv                 4.0             13.0
# 200  13.0     18.0    r         suv                 5.0             15.5
# 202  16.0     20.0    r      pickup                 4.0             18.0
# 205  15.0     19.0    r      pickup                 4.0             17.0
# 207  16.0     20.0    r      pickup                 4.0             18.0
# 209  19.0     26.0    r     compact                 7.0             22.5
# 211  22.0     29.0    p     compact                 7.0             25.5
# 215  19.0     26.0    r     compact                 7.0             22.5
# 216  22.0     29.0    p     compact                 7.0             25.5
# 218  21.0     29.0    r     compact                 8.0             25.0
# 220  16.0     23.0    r     compact                 7.0             19.5
# 223  29.0     41.0    d  subcompact                12.0             35.0
# 225  19.0     26.0    r  subcompact                 7.0             22.5
# 227  20.0     29.0    r  subcompact                 9.0             24.5
# 229  18.0     29.0    p     midsize                11.0             23.5
# 230  19.0     28.0    p     midsize                 9.0             23.5
# 232  16.0     26.0    p     midsize                10.0             21.0
# 234  17.0     26.0    p     midsize                 9.0             21.5
# 0     NaN      NaN  NaN         NaN                 NaN              NaN
#
#     is_automatic
# 1          False
# 4           True
# 5          False
# 7          False
# 9          False
# 11          True
# 12         False
# 14         False
# 16          True
# 17          True
# 18          True
# 19          True
# 20          True
# 21          True
# 22          True
# 23         False
# 25         False
# 27         False
# 29          True
# 30          True
# 31          True
# 32          True
# 33          True
# 34          True
# 35          True
# 36          True
# 37          True
# 38          True
# 39          True
# 40          True
# 41          True
# 42          True
# 43          True
# 44          True
# 45          True
# 46          True
# 47          True
# 48         False
# 50          True
# 51         False
# 53          True
# 54          True
# 55         False
# 57          True
# 58          True
# 59          True
# 60          True
# 61          True
# 62          True
# 63          True
# 64         False
# 66          True
# 67          True
# 68         False
# 71         False
# 73          True
# 74          True
# 75          True
# 76          True
# 77          True
# 78         False
# 80          True
# 81          True
# 82          True
# 83          True
# 84         False
# 87          True
# 88          True
# 89          True
# 90         False
# 92         False
# 94          True
# 95         False
# 98         False
# 101        False
# 104        False
# 106         True
# 107        False
# 109        False
# 111        False
# 113        False
# 115         True
# 116        False
# 119         True
# 120        False
# 123         True
# 124         True
# 125         True
# 126         True
# 127         True
# 128         True
# 129         True
# 130         True
# 131         True
# 132         True
# 133         True
# 134         True
# 135         True
# 136         True
# 137         True
# 138         True
# 139         True
# 140         True
# 141        False
# 143         True
# 144        False
# 147         True
# 148        False
# 150         True
# 151        False
# 153         True
# 154         True
# 155         True
# 156         True
# 157         True
# 158         True
# 159        False
# 161        False
# 164         True
# 165         True
# 166        False
# 169         True
# 170         True
# 171        False
# 175         True
# 176        False
# 178         True
# 179        False
# 181        False
# 183         True
# 184        False
# 186         True
# 187        False
# 190         True
# 191        False
# 193         True
# 194         True
# 195        False
# 198         True
# 199         True
# 200        False
# 202        False
# 205        False
# 207        False
# 209        False
# 211        False
# 215         True
# 216        False
# 218        False
# 220        False
# 223        False
# 225        False
# 227        False
# 229         True
# 230        False
# 232        False
# 234          NaN
# 0           True
